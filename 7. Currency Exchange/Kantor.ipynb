# %%
import requests
import pandas as pd

# %%
#dane z http://api.nbp.pl/en.html
response = requests.get('http://api.nbp.pl/api/exchangerates/tables/a?format=json')

# %%
data = response.json()[0]
data
# Out:
# {'table': 'A',
#  'no': '234/A/NBP/2021',
#  'effectiveDate': '2021-12-03',
#  'rates': [{'currency': 'bat (Tajlandia)', 'code': 'THB', 'mid': 0.12},
#   {'currency': 'dolar amerykański', 'code': 'USD', 'mid': 4.0653},
#   {'currency': 'dolar australijski', 'code': 'AUD', 'mid': 2.8676},
#   {'currency': 'dolar Hongkongu', 'code': 'HKD', 'mid': 0.5218},
#   {'currency': 'dolar kanadyjski', 'code': 'CAD', 'mid': 3.1702},
#   {'currency': 'dolar nowozelandzki', 'code': 'NZD', 'mid': 2.7556},
#   {'currency': 'dolar singapurski', 'code': 'SGD', 'mid': 2.9656},
#   {'currency': 'euro', 'code': 'EUR', 'mid': 4.5934},
#   {'currency': 'forint (Węgry)', 'code': 'HUF', 'mid': 0.01263},
#   {'currency': 'frank szwajcarski', 'code': 'CHF', 'mid': 4.4165},
#   {'currency': 'funt szterling', 'code': 'GBP', 'mid': 5.4021},
#   {'currency': 'hrywna (Ukraina)', 'code': 'UAH', 'mid': 0.1489},
#   {'currency': 'jen (Japonia)', 'code': 'JPY', 'mid': 0.035879},
#   {'currency': 'korona czeska', 'code': 'CZK', 'mid': 0.1808},
#   {'currency': 'korona duńska', 'code': 'DKK', 'mid': 0.6177},
#   {'currency': 'korona islandzka', 'code': 'ISK', 'mid': 0.03129},
#   {'currency': 'korona norweska', 'code': 'NOK', 'mid': 0.4463},
#   {'currency': 'korona szwedzka', 'code': 'SEK', 'mid': 0.4463},
#   {'currency': 'kuna (Chorwacja)', 'code': 'HRK', 'mid': 0.6102},
#   {'currency': 'lej rumuński', 'code': 'RON', 'mid': 0.928},
#   {'currency': 'lew (Bułgaria)', 'code': 'BGN', 'mid': 2.3485},
#   {'currency': 'lira turecka', 'code': 'TRY', 'mid': 0.2946},
#   {'currency': 'nowy izraelski szekel', 'code': 'ILS', 'mid': 1.2891},
#   {'currency': 'peso chilijskie', 'code': 'CLP', 'mid': 0.004855},
#   {'currency': 'peso filipińskie', 'code': 'PHP', 'mid': 0.0805},
#   {'currency': 'peso meksykańskie', 'code': 'MXN', 'mid': 0.191},
#   {'currency': 'rand (Republika Południowej Afryki)',
#    'code': 'ZAR',
#    'mid': 0.2543},
#   {'currency': 'real (Brazylia)', 'code': 'BRL', 'mid': 0.72},
#   {'currency': 'ringgit (Malezja)', 'code': 'MYR', 'mid': 0.9608},
#   {'currency': 'rubel rosyjski', 'code': 'RUB', 'mid': 0.0552},
#   {'currency': 'rupia indonezyjska', 'code': 'IDR', 'mid': 0.00028236},
#   {'currency': 'rupia indyjska', 'code': 'INR', 'mid': 0.05277},
#   {'currency': 'won południowokoreański', 'code': 'KRW', 'mid': 0.003439},
#   {'currency': 'yuan renminbi (Chiny)', 'code': 'CNY', 'mid': 0.6381},
#   {'currency': 'SDR (MFW)', 'code': 'XDR', 'mid': 5.6734}]}

# %%
df = pd.DataFrame(data)

# %%
df['currency'] = df['rates'].map(lambda x: x['currency'])
df['code'] = df['rates'].map(lambda x: x['code'])
df['mid'] = df['rates'].map(lambda x: x['mid'])

# %%
df = df.drop(["rates"], axis = 1)

# %%
df
# Out:
#    table              no effectiveDate                             currency  \
# 0      A  234/A/NBP/2021    2021-12-03                      bat (Tajlandia)
# 1      A  234/A/NBP/2021    2021-12-03                    dolar amerykański
# 2      A  234/A/NBP/2021    2021-12-03                   dolar australijski
# 3      A  234/A/NBP/2021    2021-12-03                      dolar Hongkongu
# 4      A  234/A/NBP/2021    2021-12-03                     dolar kanadyjski
# 5      A  234/A/NBP/2021    2021-12-03                  dolar nowozelandzki
# 6      A  234/A/NBP/2021    2021-12-03                    dolar singapurski
# 7      A  234/A/NBP/2021    2021-12-03                                 euro
# 8      A  234/A/NBP/2021    2021-12-03                       forint (Węgry)
# 9      A  234/A/NBP/2021    2021-12-03                    frank szwajcarski
# 10     A  234/A/NBP/2021    2021-12-03                       funt szterling
# 11     A  234/A/NBP/2021    2021-12-03                     hrywna (Ukraina)
# 12     A  234/A/NBP/2021    2021-12-03                        jen (Japonia)
# 13     A  234/A/NBP/2021    2021-12-03                        korona czeska
# 14     A  234/A/NBP/2021    2021-12-03                        korona duńska
# 15     A  234/A/NBP/2021    2021-12-03                     korona islandzka
# 16     A  234/A/NBP/2021    2021-12-03                      korona norweska
# 17     A  234/A/NBP/2021    2021-12-03                      korona szwedzka
# 18     A  234/A/NBP/2021    2021-12-03                     kuna (Chorwacja)
# 19     A  234/A/NBP/2021    2021-12-03                         lej rumuński
# 20     A  234/A/NBP/2021    2021-12-03                       lew (Bułgaria)
# 21     A  234/A/NBP/2021    2021-12-03                         lira turecka
# 22     A  234/A/NBP/2021    2021-12-03                nowy izraelski szekel
# 23     A  234/A/NBP/2021    2021-12-03                      peso chilijskie
# 24     A  234/A/NBP/2021    2021-12-03                     peso filipińskie
# 25     A  234/A/NBP/2021    2021-12-03                    peso meksykańskie
# 26     A  234/A/NBP/2021    2021-12-03  rand (Republika Południowej Afryki)
# 27     A  234/A/NBP/2021    2021-12-03                      real (Brazylia)
# 28     A  234/A/NBP/2021    2021-12-03                    ringgit (Malezja)
# 29     A  234/A/NBP/2021    2021-12-03                       rubel rosyjski
# 30     A  234/A/NBP/2021    2021-12-03                   rupia indonezyjska
# 31     A  234/A/NBP/2021    2021-12-03                       rupia indyjska
# 32     A  234/A/NBP/2021    2021-12-03              won południowokoreański
# 33     A  234/A/NBP/2021    2021-12-03                yuan renminbi (Chiny)
# 34     A  234/A/NBP/2021    2021-12-03                            SDR (MFW)
#
#    code       mid
# 0   THB  0.120000
# 1   USD  4.065300
# 2   AUD  2.867600
# 3   HKD  0.521800
# 4   CAD  3.170200
# 5   NZD  2.755600
# 6   SGD  2.965600
# 7   EUR  4.593400
# 8   HUF  0.012630
# 9   CHF  4.416500
# 10  GBP  5.402100
# 11  UAH  0.148900
# 12  JPY  0.035879
# 13  CZK  0.180800
# 14  DKK  0.617700
# 15  ISK  0.031290
# 16  NOK  0.446300
# 17  SEK  0.446300
# 18  HRK  0.610200
# 19  RON  0.928000
# 20  BGN  2.348500
# 21  TRY  0.294600
# 22  ILS  1.289100
# 23  CLP  0.004855
# 24  PHP  0.080500
# 25  MXN  0.191000
# 26  ZAR  0.254300
# 27  BRL  0.720000
# 28  MYR  0.960800
# 29  RUB  0.055200
# 30  IDR  0.000282
# 31  INR  0.052770
# 32  KRW  0.003439
# 33  CNY  0.638100
# 34  XDR  5.673400

# %%
#first function using pandas dataframe
def kantor():
    try:
        kod = input("Jaką walutę potrzebujesz?\nPodaj skrót, np. dla euro - 'EUR'\n").upper()
        kwota = int(input("Jaką kwotę potrzebujesz?\n"))
        kod = str(kod)
        wybrana_waluta = df[df['code'] == kod]
        waluta = wybrana_waluta['currency'].values[0]
        wybrana_waluta = float(wybrana_waluta['mid'].to_numpy())
        print(f"Za {kwota} {waluta} '{kod}' musisz zapłacić {round(wybrana_waluta * kwota,2)} zł.")
    except TypeError:
        print("Podano złe dane")

# %%
kantor()
# Out:
# Jaką walutę potrzebujesz?
# Podaj skrót, np. dla euro - 'EUR'
# idr
# Jaką kwotę potrzebujesz?
# 101
# Za 101 rupia indonezyjska 'IDR' musisz zapłacić 0.03 zł.

# %%
#2nd function without dataframe
def kantor2():
    kod = input("Jaką walutę potrzebujesz?\nPodaj skrót, np. dla euro - 'EUR'\n").upper()
    kwota = int(input("Jaką kwotę potrzebujesz?\n"))
    kod = str(kod)
    rates = data['rates']
    for rate in rates:
        if rate['code'] == kod:
            kod = rate['code']
            waluta = rate['currency']
            wartosc_waluty = rate['mid']
            print(f"Za {kwota} {waluta} '{kod}' musisz zapłacić {round(wartosc_waluty * kwota,2)} zł.")
        else:
            None

# %%
kantor2()
# Out:
# Jaką walutę potrzebujesz?
# Podaj skrót, np. dla euro - 'EUR'
# nok
# Jaką kwotę potrzebujesz?
# 150
# Za 150 korona norweska 'NOK' musisz zapłacić 66.94 zł.
